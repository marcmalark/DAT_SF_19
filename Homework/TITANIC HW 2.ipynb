# %%
import numpy as np
import pandas as pd

from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
df = pd.DataFrame.from_csv("../data/titanic.csv")

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df[df.Survived==0]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 17                  0       3
# 19                  0       3
# 21                  0       2
# 25                  0       3
# 27                  0       3
# 28                  0       1
# 30                  0       3
# 31                  0       1
# 34                  0       2
# 35                  0       1
# 36                  0       1
# 38                  0       3
# 39                  0       3
# 41                  0       3
# 42                  0       2
# 43                  0       3
# 46                  0       3
# 47                  0       3
# 49                  0       3
# 50                  0       3
# 51                  0       3
# 52                  0       3
# ...               ...     ...
# 845                 0       3
# 846                 0       3
# 847                 0       3
# 848                 0       3
# 849                 0       2
# 851                 0       3
# 852                 0       3
# 853                 0       3
# 855                 0       2
# 860                 0       3
# 861                 0       3
# 862                 0       2
# 864                 0       3
# 865                 0       2
# 868                 0       1
# 869                 0       3
# 871                 0       3
# 873                 0       1
# 874                 0       3
# 877                 0       3
# 878                 0       3
# 879                 0       3
# 882                 0       3
# 883                 0       3
# 884                 0       2
# 885                 0       3
# 886                 0       3
# 887                 0       2
# 889                 0       3
# 891                 0       3
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 5                                     Allen, Mr. William Henry    male   35
# 6                                             Moran, Mr. James    male  NaN
# 7                                      McCarthy, Mr. Timothy J    male   54
# 8                               Palsson, Master. Gosta Leonard    male    2
# 13                              Saundercock, Mr. William Henry    male   20
# 14                                 Andersson, Mr. Anders Johan    male   39
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female   14
# 17                                        Rice, Master. Eugene    male    2
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female   31
# 21                                        Fynney, Mr. Joseph J    male   35
# 25                               Palsson, Miss. Torborg Danira  female    8
# 27                                     Emir, Mr. Farred Chehab    male  NaN
# 28                              Fortune, Mr. Charles Alexander    male   19
# 30                                         Todoroff, Mr. Lalio    male  NaN
# 31                                    Uruchurtu, Don. Manuel E    male   40
# 34                                       Wheadon, Mr. Edward H    male   66
# 35                                     Meyer, Mr. Edgar Joseph    male   28
# 36                              Holverson, Mr. Alexander Oskar    male   42
# 38                                    Cann, Mr. Ernest Charles    male   21
# 39                          Vander Planke, Miss. Augusta Maria  female   18
# 41              Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female   40
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...  female   27
# 43                                         Kraeff, Mr. Theodor    male  NaN
# 46                                    Rogers, Mr. William John    male  NaN
# 47                                           Lennon, Mr. Denis    male  NaN
# 49                                         Samaan, Mr. Youssef    male  NaN
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female   18
# 51                                  Panula, Master. Juha Niilo    male    7
# 52                                Nosworthy, Mr. Richard Cater    male   21
# ...                                                        ...     ...  ...
# 845                                        Culumovic, Mr. Jeso    male   17
# 846                                        Abbing, Mr. Anthony    male   42
# 847                                   Sage, Mr. Douglas Bullen    male  NaN
# 848                                         Markoff, Mr. Marin    male   35
# 849                                          Harper, Rev. John    male   28
# 851                    Andersson, Master. Sigvard Harald Elias    male    4
# 852                                        Svensson, Mr. Johan    male   74
# 853                                    Boulos, Miss. Nourelain  female    9
# 855              Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female   44
# 860                                           Razi, Mr. Raihed    male  NaN
# 861                                    Hansen, Mr. Claus Peter    male   41
# 862                                Giles, Mr. Frederick Edward    male   21
# 864                          Sage, Miss. Dorothy Edith "Dolly"  female  NaN
# 865                                     Gill, Mr. John William    male   24
# 868                       Roebling, Mr. Washington Augustus II    male   31
# 869                                van Melkebeke, Mr. Philemon    male  NaN
# 871                                          Balkic, Mr. Cerin    male   26
# 873                                   Carlsson, Mr. Frans Olof    male   33
# 874                                Vander Cruyssen, Mr. Victor    male   47
# 877                              Gustafsson, Mr. Alfred Ossian    male   20
# 878                                       Petroff, Mr. Nedelio    male   19
# 879                                         Laleff, Mr. Kristo    male  NaN
# 882                                         Markun, Mr. Johann    male   33
# 883                               Dahlberg, Miss. Gerda Ulrika  female   22
# 884                              Banfield, Mr. Frederick James    male   28
# 885                                     Sutehall, Mr. Henry Jr    male   25
# 886                       Rice, Mrs. William (Margaret Norton)  female   39
# 887                                      Montvila, Rev. Juozas    male   27
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  NaN
# 891                                        Dooley, Mr. Patrick    male   32
#
#              SibSp  Parch            Ticket      Fare        Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171    7.2500          NaN        S
# 5                0      0            373450    8.0500          NaN        S
# 6                0      0            330877    8.4583          NaN        Q
# 7                0      0             17463   51.8625          E46        S
# 8                3      1            349909   21.0750          NaN        S
# 13               0      0         A/5. 2151    8.0500          NaN        S
# 14               1      5            347082   31.2750          NaN        S
# 15               0      0            350406    7.8542          NaN        S
# 17               4      1            382652   29.1250          NaN        Q
# 19               1      0            345763   18.0000          NaN        S
# 21               0      0            239865   26.0000          NaN        S
# 25               3      1            349909   21.0750          NaN        S
# 27               0      0              2631    7.2250          NaN        C
# 28               3      2             19950  263.0000  C23 C25 C27        S
# 30               0      0            349216    7.8958          NaN        S
# 31               0      0          PC 17601   27.7208          NaN        C
# 34               0      0        C.A. 24579   10.5000          NaN        S
# 35               1      0          PC 17604   82.1708          NaN        C
# 36               1      0            113789   52.0000          NaN        S
# 38               0      0        A./5. 2152    8.0500          NaN        S
# 39               2      0            345764   18.0000          NaN        S
# 41               1      0              7546    9.4750          NaN        S
# 42               1      0             11668   21.0000          NaN        S
# 43               0      0            349253    7.8958          NaN        C
# 46               0      0   S.C./A.4. 23567    8.0500          NaN        S
# 47               1      0            370371   15.5000          NaN        Q
# 49               2      0              2662   21.6792          NaN        C
# 50               1      0            349237   17.8000          NaN        S
# 51               4      1           3101295   39.6875          NaN        S
# 52               0      0        A/4. 39886    7.8000          NaN        S
# ...            ...    ...               ...       ...          ...      ...
# 845              0      0            315090    8.6625          NaN        S
# 846              0      0         C.A. 5547    7.5500          NaN        S
# 847              8      2          CA. 2343   69.5500          NaN        S
# 848              0      0            349213    7.8958          NaN        C
# 849              0      1            248727   33.0000          NaN        S
# 851              4      2            347082   31.2750          NaN        S
# 852              0      0            347060    7.7750          NaN        S
# 853              1      1              2678   15.2458          NaN        C
# 855              1      0            244252   26.0000          NaN        S
# 860              0      0              2629    7.2292          NaN        C
# 861              2      0            350026   14.1083          NaN        S
# 862              1      0             28134   11.5000          NaN        S
# 864              8      2          CA. 2343   69.5500          NaN        S
# 865              0      0            233866   13.0000          NaN        S
# 868              0      0          PC 17590   50.4958          A24        S
# 869              0      0            345777    9.5000          NaN        S
# 871              0      0            349248    7.8958          NaN        S
# 873              0      0               695    5.0000  B51 B53 B55        S
# 874              0      0            345765    9.0000          NaN        S
# 877              0      0              7534    9.8458          NaN        S
# 878              0      0            349212    7.8958          NaN        S
# 879              0      0            349217    7.8958          NaN        S
# 882              0      0            349257    7.8958          NaN        S
# 883              0      0              7552   10.5167          NaN        S
# 884              0      0  C.A./SOTON 34068   10.5000          NaN        S
# 885              0      0   SOTON/OQ 392076    7.0500          NaN        S
# 886              0      5            382652   29.1250          NaN        Q
# 887              0      0            211536   13.0000          NaN        S
# 889              1      2        W./C. 6607   23.4500          NaN        S
# 891              0      0            370376    7.7500          NaN        Q
#
# [549 rows x 11 columns]

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.Pclass, df.Survived, random_state=1)

# %%
print X_train.shape
print X_train
# Out:
# (668,)
# PassengerId
# 36     1
# 47     3
# 454    1
# 292    1
# 749    1
# 42     2
# 225    1
# 341    2
# 126    3
# 804    3
# 801    2
# 109    3
# 579    3
# 889    3
# 594    3
# 551    1
# 1      3
# 685    2
# 530    2
# 245    3
# 75     3
# 161    3
# 745    3
# 67     2
# 577    2
# 737    3
# 413    1
# 762    3
# 511    3
# 742    1
#       ..
# 87     3
# 479    3
# 504    3
# 754    3
# 216    1
# 581    2
# 563    2
# 399    2
# 669    3
# 491    3
# 253    1
# 469    3
# 358    2
# 255    3
# 277    3
# 179    2
# 282    3
# 391    1
# 509    3
# 750    3
# 584    1
# 130    3
# 145    2
# 848    3
# 646    1
# 716    3
# 768    3
# 73     2
# 236    3
# 38     3
# Name: Pclass, dtype: int64

# %%
X_test.shape
# Out:
# (223,)

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-38cbfcae5931> in <module>()
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 nb = MultinomialNB()
# ----> 3 nb.fit(X_train, y_train)
#
# /Users/Computer/anaconda/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     472             Returns self.
#     473         """
# --> 474         X, y = check_X_y(X, y, 'csr')
#     475         _, n_features = X.shape
#     476
#
# /Users/Computer/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric)
#     452         y = y.astype(np.float64)
#     453
# --> 454     check_consistent_length(X, y)
#     455
#     456     return X, y
#
# /Users/Computer/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     172     if len(uniques) > 1:
#     173         raise ValueError("Found arrays with inconsistent numbers of samples: "
# --> 174                          "%s" % str(uniques))
#     175
#     176
#
# ValueError: Found arrays with inconsistent numbers of samples: [  1 668]
